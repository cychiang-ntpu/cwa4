# %%
from cwa4.dataset import Dataset4

# %%
dataset = Dataset4(
    gnss_path="hualian_daily_gnss_dXdYdU.pkl",
    statistics_path="hualian_daily_statistics.pkl", 
    target_path="hualian_target_cnt.pkl"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.cache/uv/archive-v0/y4ASxpl0D7M0jaBsfJznB/lib/python3.12/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#
# ModuleNotFoundError: No module named 'numpy._core.numeric'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataset = Dataset4(
#       2     gnss_path="hualian_daily_gnss_dXdYdU.pkl",
#       3     statistics_path="hualian_daily_statistics.pkl",
#       4     target_path="hualian_target_cnt.pkl"
#       5 )
#
# File ~/Projects/cwa_project4/src/cwa4/dataset.py:111, in Dataset4.__init__(self, gnss_path, statistics_path, target_path, input_width, target_width, subset)
#     102 def __init__(
#     103         self,
#     104         gnss_path="data/hualian_daily_gnss_dXdYdU.pkl",
#    (...)    108         target_width=1,
#     109         subset="trn"):
#     110     super().__init__()
# --> 111     df0 = pd.read_pickle(gnss_path)
#     112     df1 = pd.read_pickle(statistics_path)
#     113     df2 = pd.read_pickle(target_path)
#
# File ~/.cache/uv/archive-v0/y4ASxpl0D7M0jaBsfJznB/lib/python3.12/site-packages/pandas/io/pickle.py:207, in read_pickle(filepath_or_buffer, compression, storage_options)
#     202             return pickle.load(handles.handle)
#     203     except excs_to_catch:
#     204         # e.g.
#     205         #  "No module named 'pandas.core.sparse.series'"
#     206         #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 207         return pc.load(handles.handle, encoding=None)
#     208 except UnicodeDecodeError:
#     209     # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#     210     return pc.load(handles.handle, encoding="latin-1")
#
# File ~/.cache/uv/archive-v0/y4ASxpl0D7M0jaBsfJznB/lib/python3.12/site-packages/pandas/compat/pickle_compat.py:231, in load(fh, encoding, is_verbose)
#     228     # "Unpickler" has no attribute "is_verbose"  [attr-defined]
#     229     up.is_verbose = is_verbose  # type: ignore[attr-defined]
# --> 231     return up.load()
#     232 except (ValueError, TypeError):
#     233     raise
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python3.12/pickle.py:1256, in _Unpickler.load(self)
#    1254             raise EOFError
#    1255         assert isinstance(key, bytes_types)
# -> 1256         dispatch[key[0]](self)
#    1257 except _Stop as stopinst:
#    1258     return stopinst.value
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python3.12/pickle.py:1581, in _Unpickler.load_stack_global(self)
#    1579 if type(name) is not str or type(module) is not str:
#    1580     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1581 self.append(self.find_class(module, name))
#
# File ~/.cache/uv/archive-v0/y4ASxpl0D7M0jaBsfJznB/lib/python3.12/site-packages/pandas/compat/pickle_compat.py:162, in Unpickler.find_class(self, module, name)
#     160 key = (module, name)
#     161 module, name = _class_locations_map.get(key, key)
# --> 162 return super().find_class(module, name)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python3.12/pickle.py:1622, in _Unpickler.find_class(self, module, name)
#    1620     elif module in _compat_pickle.IMPORT_MAPPING:
#    1621         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1622 __import__(module, level=0)
#    1623 if self.proto >= 4:
#    1624     return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'numpy._core.numeric'
